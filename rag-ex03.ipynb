# %%
# %pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting lxml>=3.1.0 (from python-docx)
#   Downloading lxml-5.4.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\h\miniconda3\envs\project\lib\site-packages (from python-docx) (4.13.2)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
# Downloading lxml-5.4.0-cp310-cp310-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------------------ --------------- 2.4/3.8 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 10.8 MB/s eta 0:00:00
# Installing collected packages: lxml, python-docx
# Successfully installed lxml-5.4.0 python-docx-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 1. 문서 내용 읽기

# %% [markdown]
# -python-docx

# %%
from docx import Document

document = Document('law_1.docx')
document

# %%
dir(document)
# Out:
# ['_Document__body',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_block_width',
#  '_body',
#  '_element',
#  '_parent',
#  '_part',
#  'add_heading',
#  'add_page_break',
#  'add_paragraph',
#  'add_picture',
#  'add_section',
#  'add_table',
#  'core_properties',
#  'element',
#  'inline_shapes',
#  'iter_inner_content',
#  'paragraphs',
#  'part',
#  'save',
#  'sections',
#  'settings',
#  'styles',
#  'tables']

# %%
print(dir(document))
# Out:
# ['_Document__body', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_block_width', '_body', '_element', '_parent', '_part', 'add_heading', 'add_page_break', 'add_paragraph', 'add_picture', 'add_section', 'add_table', 'core_properties', 'element', 'inline_shapes', 'iter_inner_content', 'paragraphs', 'part', 'save', 'sections', 'settings', 'styles', 'tables']

# %%
document.paragraphs[0].text
# Out:
# ''

# %%
type(document.paragraphs)
# Out:
# list

# %%
for index, paragraph in enumerate(document.paragraphs):
    print(f'{index}. {paragraph.text}')

    if index == 4:
        break
# Out:
# 0.
# 1. 전세사기피해자 지원 및 주거안정에 관한 특별법 ( 약칭: 전세사기피해자법 )
# 2. [시행 2024. 11. 11.] [법률 제20429호, 2024. 9. 10., 일부개정]
# 3.
# 4. 국토교통부(피해지원총괄과) 044-201-5233, 5234

# %%
## 읽어 온 단락을 하나의 문서로 만들기
full_text = ''

for para in document.paragraphs:
    full_text += para.text + '\n'  # 문단별 줄바꿈 포함

# %%
print(full_text[:500])
# Out:
# 전세사기피해자 지원 및 주거안정에 관한 특별법 ( 약칭: 전세사기피해자법 )
# [시행 2024. 11. 11.] [법률 제20429호, 2024. 9. 10., 일부개정]
#
# 국토교통부(피해지원총괄과) 044-201-5233, 5234
#
#        제1장 총칙
# 제1조(목적) 이 법은 전세사기로 피해를 입은 임차인에게 경ㆍ공매 절차 및 조세 징수 등에 관한 특례를 부여함으로써 전세사기피해자를 지원하고 주거안정을 도모함을 목적으로 한다.
# 제2조(정의) 이 법에서 사용하는 용어의 정의는 다음과 같다. <개정 2024. 9. 10.>
#   1. “주택”이란 「주택임대차보호법」 제2조에 따른 주거용 건물(공부상 주거용 건물이 아니라도 임대차계약 체결 당시 임대차목적물의 구조와 실질이 주거용 건물이고 임차인의 실제 용도가 주거용인 경우를 포함한다)을 말한다.
#   2. “임대인등”이란 임대인 또는 다음 각 목의 어느 하나에 해당하는 자를 말한다.
#     가. 임대인의 대리인, 그 밖에 임대인을

# %% [markdown]
# # 문

# %%
# %pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in c:\users\h\miniconda3\envs\project\lib\site-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\h\miniconda3\envs\project\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\h\miniconda3\envs\project\lib\site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\h\miniconda3\envs\project\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h\miniconda3\envs\project\lib\site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\h\miniconda3\envs\project\lib\site-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h\miniconda3\envs\project\lib\site-packages (from requests>=2.26.0->tiktoken) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tiktoken

encoding_model = tiktoken.encoding_for_model('gpt-4o')
encoding_model
# Out:
# <Encoding 'o200k_base'>

# %%
## 토큰화
encoding = encoding_model.encode(full_text)
print(encoding)
# Out:
# [198, 9516, 11734, 5537, 4283, 31361, 5650, 5947, 59898, 23891, 16130, 17077, 14307, 7329, 3107, 137026, 136828, 22070, 350, 58496, 125775, 25, 12946, 11734, 5537, 4283, 31361, 5650, 5947, 22070, 3270, 58, 5637, 15719, 220, 1323, 19, 13, 220, 994, 13, 220, 994, 54569, 723, 22070, 73888, 14377, 14397, 2270, 16684, 11, 220, 1323, 19, 13, 220, 24, 13, 220, 702, 4213, 124313, 13915, 7329, 3144, 12018, 24707, 20130, 22960, 9814, 7, 31361, 5650, 170669, 65553, 109850, 226, 8562, 8, 220, 35132, 12, 667, 12, 39833, 18, 11, 220, 39833, 19, 279, 1699, 14377, 16, 7681, 64009, 90720, 793, 8021, 16, 14844, 7, 25816, 9871, 8, 6548, 69826, 4740, 12946, 11734, 5537, 152240, 143474, 4831, 27995, 4740, 69248, 20981, 5544, 34950, 17357, 166757, 12809, 20356, 83206, 20981, 23891, 21853, 11734, 8325, 243, 7820, 184983, 137026, 39359, 69361, 4831, 20211, 11423, 26077, 9911, 102717, 12946, 11734, 5537, 4283, 31361, 5650, 89174, 59898, 17231, 16130, 17077, 14307, 90056, 27433, 17267, 26077, 3281, 43878, 34555, 46609, 558, 8021, 17, 14844, 7, 7329, 3408, 8, 6548, 69826, 11440, 176781, 82342, 5959, 3408, 153254, 2770, 68527, 8562, 179779, 13, 464, 13915, 7329, 220, 1323, 19, 13, 220, 24, 13, 220, 702, 13, 523, 220, 220, 16, 13, 966, 9273, 29871, 693, 2186, 43514, 36702, 9273, 29871, 20043, 8092, 20981, 8122, 16684, 22070, 5252, 14377, 17, 14844, 3107, 156265, 16130, 17077, 8423, 43086, 19948, 7, 12809, 9814, 8612, 16130, 17077, 8423, 43086, 195357, 77380, 5827, 69248, 8092, 20981, 15450, 25941, 55005, 27188, 160483, 69248, 8092, 20981, 25816, 9871, 19948, 3408, 158440, 12753, 27365, 30570, 2186, 16130, 17077, 8423, 43086, 19948, 88647, 69248, 20981, 129039, 112933, 82342, 148791, 16130, 17077, 8423, 5544, 33502, 4831, 79778, 29423, 138973, 27202, 29423, 558, 220, 220, 17, 13, 966, 20043, 8092, 5544, 24725, 693, 2186, 43514, 69248, 8092, 5544, 63618, 68527, 57106, 43878, 3408, 138744, 49396, 3107, 85127, 14108, 15508, 4831, 27202, 29423, 558, 271, 9919, 13, 69248, 8092, 129039, 10985, 4960, 5544, 11, 10599, 174670, 3107, 69248, 8092, 139963, 16302, 31412, 16130, 29871, 3408, 69248, 8092, 3107, 21927, 31412, 147832, 4831, 98436, 14108, 15508, 198, 271, 17743, 13, 69248, 8092, 129039, 24099, 145796, 4831, 162698, 19010, 5544, 19684, 13915, 5537, 7, 19684, 13915, 8122, 14844, 139963, 79778, 29423, 446, 271, 14367, 13, 69248, 8092, 139963, 16302, 31412, 69248, 20981, 139963, 181041, 14108, 15508, 7, 11946, 50422, 3956, 8423, 139963, 79778, 29423, 446, 271, 55808, 13, 14367, 7820, 69248, 8092, 129039, 33628, 21206, 3107, 21023, 184390, 5544, 198, 271, 21096, 13, 55808, 25816, 3408, 184390, 117970, 12688, 27798, 161286, 110848, 9871, 6548, 61450, 3281, 115448, 14108, 182710, 198, 271, 22796, 13, 55808, 25816, 3408, 184390, 5544, 72983, 21096, 25816, 3408, 182710, 3281, 33628, 21206, 3107, 105137, 242, 14367, 7820, 3408, 69248, 8092, 5544, 198, 220, 220, 18, 13, 966, 9516, 11734, 5537, 4283, 31361, 5650, 5947, 693, 43514, 14377, 18, 14844, 3408, 38257, 23459, 3281, 67168, 95933, 137024, 15508, 3710, 4865, 14377, 21, 14844, 3107, 156265, 12946, 11734, 5537, 4283, 31361, 5650, 170669, 120354, 129407, 61505, 3408, 166757, 3408, 27188, 3281, 29929, 70032, 31077, 24707, 20130, 22960, 9814, 7681, 15853, 2186, 120255, 3748, 69248, 20981, 139963, 27202, 29423, 558, 220, 220, 19, 13, 966, 9516, 11734, 5537, 4283, 31361, 5650, 5947, 24725, 693, 2186, 43514, 68527, 57106, 43878, 3408, 138744, 49396, 3107, 85127, 14108, 15508, 4831, 27202, 29423, 558, 271, 9919, 13, 12946, 11734, 5537, 4283, 31361, 5650, 5947, 198, 271, 17743, 13, 14377, 18, 14844, 8021, 16, 31275, 8021, 16, 16684, 166757, 8021, 18, 16684, 23891, 14377, 19, 16684, 3408, 38257, 23459, 3281, 67168, 71712, 43129, 14108, 15508, 7, 50771, 4740, 21853, 14377, 17, 31275, 57106, 45676, 3408, 138744, 49396, 3107, 85127, 14108, 33502, 2770, 174926, 29423, 8, 3710, 4865, 14377, 21, 14844, 3107, 156265, 12946, 11734, 5537, 4283, 31361, 5650, 170669, 120354, 129407, 61505, 3408, 166757, 3408, 27188, 3281, 29929, 70032 ...

# %%
# 9516, 11734, 5537
decoding = encoding_model.decode([9516])
decoding
# Out:
# '전'

# %%
decoding = encoding_model.decode([11734])
decoding
# Out:
# '세'

# %%
decoding = encoding_model.decode([5537])
decoding
# Out:
# '사'

# %%
len(encoding)
# Out:
# 19039

# %%
def split_text(full_text, chunk_size):
    encoder_model = tiktoken.encoding_for_model('gpt-4o')
